# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# ### Mohammad Hamzah.
#
#  Data Scientist.

# %% [markdown]
# *Because I love Data.*

# %% [markdown]
# ### The Following def is adding a number to another

# %%
a = 1
b = 2
print (a+b)
# Out:
# 3

# %% [markdown]
# -1
#
# -2
#
# -3
